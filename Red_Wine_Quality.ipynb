# %% [markdown]
# <a href="https://colab.research.google.com/github/MelihKlc/Deep-Learning/blob/main/Red_Wine_Quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv("winequality-red.csv")

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import make_column_transformer

scaler = MinMaxScaler()

# %%
X = dataset.drop("quality" , axis = 1)
y = dataset["quality"]
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2)
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 931             7.4             0.610         0.01             2.0      0.074
# 201             8.8             0.370         0.48             2.1      0.097
# 447             9.3             0.480         0.29             2.1      0.127
# 614             9.2             0.755         0.18             2.2      0.148
# 1189            8.8             0.955         0.05             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1219            9.0             0.390         0.40             1.3      0.044
# 842            10.6             0.500         0.45             2.6      0.119
# 1211            6.6             0.440         0.15             2.1      0.076
# 481             9.4             0.300         0.56             2.8      0.080
# 350            10.7             0.670         0.22             2.7      0.107
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 931                  13.0                  38.0  0.99748  3.48       0.65
# 201                  39.0                 145.0  0.99750  3.04       1.03
# 447                   6.0                  16.0  0.99680  3.22       0.72
# 614                  10.0                 103.0  0.99690  2.87       1.36
# 1189                  5.0                  19.0  0.99616  3.30       0.44
# ...                   ...                   ...      ...   ...        ...
# 1219                 25.0                  50.0  0.99478  3.20       0.83
# 842                  34.0                  68.0  0.99708  3.23       0.72
# 1211                 22.0                  53.0  0.99570  3.32       0.62
# 481                   6.0                  17.0  0.99640  3.15       0.92
# 350                  17.0                  34.0  1.00040  3.28       0.98
#
#       alcohol
# 931       9.8
# 201       9.3
# 447      11.2
# 614      10.2
# 1189      9.6
# ...       ...
# 1219     10.9
# 842      10.9
# 1211      9.3
# 481      11.7
# 350       9.9
#
# [1279 rows x 11 columns]

# %%
len(y_train.value_counts())
# Out:
# 6

# %%
scaled_data = scaler.fit(X_train)

X_train_normal = scaled_data.transform(X_train)
X_test_normal = scaled_data.transform(X_test)
X_train_normal
# Out:
# array([[0.24778761, 0.33561644, 0.01265823, ..., 0.53508772, 0.19753086,
#         0.21538462],
#        [0.37168142, 0.17123288, 0.60759494, ..., 0.14912281, 0.43209877,
#         0.13846154],
#        [0.4159292 , 0.24657534, 0.36708861, ..., 0.30701754, 0.24074074,
#         0.43076923],
#        ...,
#        [0.17699115, 0.21917808, 0.18987342, ..., 0.39473684, 0.17901235,
#         0.13846154],
#        [0.42477876, 0.12328767, 0.70886076, ..., 0.24561404, 0.36419753,
#         0.50769231],
#        [0.53982301, 0.37671233, 0.27848101, ..., 0.35964912, 0.40123457,
#         0.23076923]])

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential(
    [
        tf.keras.layers.Dense(1) ,
        tf.keras.layers.Dense(6)

    ]
)
model.compile(loss = tf.keras.losses.mae ,
              optimizer = tf.keras.optimizers.Adam()

              )

history = model.fit(
    X_train ,
    y_train ,
    validation_data = (X_test , y_test) ,
    epochs = 25
)
# Out:
# Epoch 1/25
# 40/40 [==============================] - 1s 6ms/step - loss: 10.3026 - val_loss: 9.4984
# Epoch 2/25
# 40/40 [==============================] - 0s 3ms/step - loss: 8.7735 - val_loss: 8.1972
# Epoch 3/25
# 40/40 [==============================] - 0s 3ms/step - loss: 7.6814 - val_loss: 7.3159
# Epoch 4/25
# 40/40 [==============================] - 0s 2ms/step - loss: 6.9545 - val_loss: 6.7231
# Epoch 5/25
# 40/40 [==============================] - 0s 3ms/step - loss: 6.4835 - val_loss: 6.3362
# Epoch 6/25
# 40/40 [==============================] - 0s 3ms/step - loss: 6.1813 - val_loss: 6.0776
# Epoch 7/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.9769 - val_loss: 5.9028
# Epoch 8/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.8339 - val_loss: 5.7675
# Epoch 9/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.7193 - val_loss: 5.6543
# Epoch 10/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.6171 - val_loss: 5.5510
# Epoch 11/25
# 40/40 [==============================] - 0s 2ms/step - loss: 5.5191 - val_loss: 5.4505
# Epoch 12/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.4188 - val_loss: 5.3440
# Epoch 13/25
# 40/40 [==============================] - 0s 2ms/step - loss: 5.3075 - val_loss: 5.2238
# Epoch 14/25
# 40/40 [==============================] - 0s 3ms/step - loss: 5.1747 - val_loss: 5.0765
# Epoch 15/25
# 40/40 [==============================] - 0s 2ms/step - loss: 5.0081 - val_loss: 4.8895
# Epoch 16/25
# 40/40 [==============================] - 0s 3ms/step - loss: 4.7965 - val_loss: 4.6640
# Epoch 17/25
# 40/40 [==============================] - 0s 3ms/step - loss: 4.5385 - val_loss: 4.3975
# Epoch 18/25
# 40/40 [==============================] - 0s 3ms/step - loss: 4.2433 - val_loss: 4.1189
# Epoch 19/25
# 40/40 [==============================] - 0s 3ms/step - loss: 3.9413 - val_loss: 3.8361
# Epoch 20/25
# 40/40 [==============================] - 0s 3ms/step - loss: 3.6335 - val_loss: 3.5332
# Epoch 21/25
# 40/40 [==============================] - 0s 3ms/step - loss: 3.3137 - val_loss: 3.2139
# Epoch 22/25
# 40/40 [==============================] - 0s 3ms/step - loss: 2.9800 - val_loss: 2.8719
# Epoch 23/25
# 40/40 [==============================] - 0s 3ms/step - loss: 2.6515 - val_loss: 2.5944
# Epoch 24/25
# 40/40 [==============================] - 0s 3ms/step - loss: 2.4229 - val_loss: 2.4183
# Epoch 25/25
# 40/40 [==============================] - 0s 3ms/step - loss: 2.2671 - val_loss: 2.2825

# %%
model.evaluate(X_test , y_test)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5067
# 0.50672847032547

# %%
pd.DataFrame(history.history).plot()
import matplotlib.pyplot as plt
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')
