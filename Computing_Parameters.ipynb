# %% [markdown]
# <a href="https://colab.research.google.com/github/MelihKlc/Deep-Learning/blob/main/Computing_Parameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
parameters = {}
L = 10 # number of layers in the network

for l in range(1, L):
        #(≈ 2 lines of code)
        # parameters['W' + str(l)] = ...
        # parameters['b' + str(l)] = ...
        # YOUR CODE STARTS HERE
        parameters["W" + str(l)] = np.random.randn(10 , 9 ) * 0.01
        parameters["b" + str(l)] = np.zeros(shape = (10 , 1) )

# %%
parameters
# Out:
# {'W1': array([[-3.32977904e-03, -1.66284880e-02, -4.89108240e-03,
#           1.42593149e-02, -1.32658116e-02, -2.12856746e-02,
#           1.66676070e-02,  1.58455950e-02,  6.12811343e-03],
#         [-4.32028095e-03,  4.54148352e-03,  1.79972124e-05,
#          -7.36748786e-03,  1.26125771e-02,  9.96245299e-03,
#           5.13341025e-03,  6.53820071e-03, -1.40320683e-02],
#         [ 9.53560162e-03,  1.11939387e-03,  1.45054013e-02,
#           1.41877366e-02,  1.26213711e-02,  9.06446999e-03,
#           1.11196018e-02,  4.70409837e-03,  2.33285364e-03],
#         [-5.69619344e-03, -1.41466327e-02, -9.97376220e-03,
#          -9.40975596e-03, -2.56356404e-03, -1.37380704e-02,
#           1.06922827e-02, -4.80767135e-03,  1.10616268e-04],
#         [ 1.10355437e-02, -1.19336916e-02, -1.14026868e-02,
#           1.88868613e-02, -9.39473002e-03, -4.09532251e-03,
#          -5.25190087e-03, -9.17888420e-03, -4.05071844e-03],
# ...
