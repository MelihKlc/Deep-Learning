# %% [markdown]
# <a href="https://colab.research.google.com/github/MelihKlc/Deep-Learning/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Integrates directly with pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot(); # This is our figure

# %%
x = [ 1 , 2 , 3 , 4]
y = [ 11 , 22 , 33 , 44 ]
plt.plot( x , y );

# %%
# First method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
# Second method
fig = plt.figure()
ax = fig.add_axes([ 1 , 1 , 1 , 1])
ax.plot(x , y) # Add some data
plt.show()

# %%
# Third method(recommended)
fig , ax = plt.subplots()  # Subplot aynı anda farklı grafikleri yanyana cizdirmek.
ax.plot(x , y);

# %% [markdown]
# ## Matplotlib example workflow
# 1. Import matplotlib.pyplot
# 2. Prepare data ( x = [ 1 , 2 , 3] , y = [ 50 , 45 , 72] )
# 3. Setup plot
#
# **fig , ax = plt.subplots(figsize = (10 , 10))  , figsize = (height , width)**
# 4. Plot data
#
# **ax.plot( x , y )**
# 3 te figure yani bütün grafiği kapsayan bölgeyi oluşturup axisleri oluşturduk şimdi axislerimize datalarımızı yerleştiriyoruz.
#
# 5. Customize plot
#
# **ax.set(title = "Simple Plot" ,**
# **xlabel = "x-axis" ,**
# **ylabel = "y-axis")**

# %% [markdown]
# ## Making figure with numpy arrays
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplot

# %%
# Create some data
x = np.linspace( 0 , 10 , 100 )
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data with line plot  ( plot() default is line )
fig , ax = plt.subplots()
ax.plot( x , x**2 );

# %%
# Use same data for scatter plot
fig , ax = plt.subplots(figsize = (10 , 7 ))
ax.scatter( x , x**2 );

# %%
# Another scatter plot
fig , ax = plt.subplots()
ax.scatter(x , np.sin(x));

# %%
# Make a plot from dictionaries
nut_butter = {
    "Almond" : 10 ,
    "Peanut": 8 ,
    "Cashew": 12
}
fig , ax = plt.subplots()
ax.bar(nut_butter.keys() , nut_butter.values() )
ax.set(
    title = "butter prices" ,
    xlabel = "Butters" ,
    ylabel = "Price"
);

# %%
# For horizontal bar plot
fig , ax = plt.subplots()
ax.barh( list( nut_butter.keys() ) , list( nut_butter.values() ) );  # barh horizontal plot için. barh parametreleri liste şeklinde alıyor bu yüzden list() methodu ile listeye ceviriyoruz.

# %%
# Histogram
# Make some data
x = np.random.randn(1000)  # Normal distribution randn
fig , ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# First option for subplot
fig , ( ( ax1 , ax2 ) , ( ax3 , ax4 ) ) = plt.subplots(
    nrows = 2 ,
    ncols = 2 ,
    figsize = ( 10 , 5 )
)
# Plot to each different axis
ax1.plot( x , x/2 );
ax2.scatter(np.random.random(10) , np.random.random(10) );
ax3.bar(nut_butter.keys() , nut_butter.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from pandas DataFrame

# %%
df = pd.read_csv("/content/car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Plotting from pandas Series
ts = pd.Series(
    np.random.randn(1000) ,
    index = pd.date_range("1/1/2020" , periods = 1000)
)
ts
# Out:
# 2020-01-01    0.547436
# 2020-01-02   -0.307679
# 2020-01-03    0.878335
# 2020-01-04    0.702839
# 2020-01-05    0.036095
#                 ...
# 2022-09-22    0.975621
# 2022-09-23   -0.926535
# 2022-09-24   -0.966901
# 2022-09-25   -1.546387
# 2022-09-26   -0.765227
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()  # Cumulative sum
ts.plot();

# %%
df["Price"] = df["Price"].str.replace('[ \$\,\. ]' , '' )
df
# Out:
# <ipython-input-34-cdab43f71c25>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Price"] = df["Price"].str.replace('[ \$\,\. ]' , '' )
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(df["Price"][0])
# Out:
# str

# %%
df["Price"] = df["Price"].str[ : -2]  # Sondan 2 sıfır sildik
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df["Sale Date"] = pd.date_range("1/1/2020" , periods = len(df))
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
df["Total sale"] = df["Price"].astype(int).cumsum()
df  # Because our price column still str type so we convert with astype
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sale
# 0  Toyota  White         150043      4   4000 2020-01-01        4000
# 1   Honda    Red          87899      4   5000 2020-01-02        9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03       16000
# 3     BMW  Black          11179      5  22000 2020-01-04       38000
# 4  Nissan  White         213095      4   3500 2020-01-05       41500
# 5  Toyota  Green          99213      4   4500 2020-01-06       46000
# 6   Honda   Blue          45698      4   7500 2020-01-07       53500
# 7   Honda   Blue          54738      4   7000 2020-01-08       60500
# 8  Toyota  White          60000      4   6250 2020-01-09       66750
# 9  Nissan  White          31600      4   9700 2020-01-10       76450

# %%
# Lets plot the total sales. DataFrame olunca direkt plot kullanabiliyoruz.
df.plot( x = "Sale Date" , y = "Total sale")
# Out:
# <Axes: xlabel='Sale Date'>

# %% [markdown]
# ### astype(int) ile integer a çeviriyoruz

# %%
# Scatter plot
df["Price"] = df["Price"].astype(int)   # ctrl + shift + 7 ile comment alıyoruz.
df.plot( x = "Odometer (KM)"  , y = "Price" , kind = "scatter");

# %%
# How about a bar graph?
x = np.random.randn( 10 , 4 )

# Turn it into a dataframe
bar = pd.DataFrame(
    x
)
bar
# Out:
#           0         1         2         3
# 0 -0.371740  0.898892 -0.046963 -0.107789
# 1  1.801845 -0.201420  0.051114 -0.219295
# 2  1.202134 -1.887948 -0.171208 -0.625050
# 3  0.125994  1.090691  0.070221  0.709900
# 4  1.429878  0.573110 -0.178164 -1.013165
# 5  0.663519  1.381364 -1.725827 -0.433786
# 6 -2.831435  0.064999 -0.942941  0.840189
# 7 -1.594730 -1.055274  0.052262 -1.892252
# 8 -1.456621  1.530823  0.178582  0.572062
# 9  0.516819  0.397728 -0.530821 -0.545506

# %%
bar.plot.bar();

# %%
df.plot(
    x = "Make" ,
    y = "Odometer (KM)" ,
    kind = "bar"
);

# %%
# How about histogram?
df["Odometer (KM)"].plot.hist(bins = 50); # x axiste kaç değer olacagını belirliyoruz bins ile. Default 10

# %%
# Heart diseas dataset
# !wget https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv
# Out:
# --2023-09-12 15:07:43--  https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11328 (11K) [text/plain]
# Saving to: ‘heart-disease.csv’
#
# heart-disease.csv   100%[===================>]  11.06K  --.-KB/s    in 0s
#
# 2023-09-12 15:07:43 (106 MB/s) - ‘heart-disease.csv’ saved [11328/11328]

# %%
heart_diseas = pd.read_csv("/content/heart-disease.csv")
heart_diseas
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram of age column
heart_diseas["age"].plot.hist();

# %%
# Plot histogram of all the columns in dataframe
heart_diseas.plot.hist(subplots = True , figsize = ( 10 , 30 ) )
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ### Which one should i use?
# * When plotting something quickly , use pyplot.
# * When plotting something advanced , use matplotlib OO method.

# %%
over_50 = heart_diseas[ heart_diseas["age"] > 50 ]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot method
over_50.plot(
    x = "age" ,
    y = "chol" ,
    c = "target" ,
    kind = "scatter"
);    # When we want to plot 2 features with their labels , we should do c = "label_name"

# %%
# OO method  ( Object-Oriented method ) mixed with pyplot method
fig , ax = plt.subplots(figsize = ( 10 , 7 ) )
over_50.plot(
    x = "age" ,
    y = "chol" ,
    c = 'target' ,
    ax = ax ,
    kind = "scatter"
)

ax.set_xlim( [ 45 , 100 ] );  # x axisin range ini değiştiriyoruz.

# %%
# OO method from scratch
fig , ax = plt.subplots(figsize = (10 , 6))

# Plot the data
scatter = ax.scatter(
    x = over_50["age"] ,
    y = over_50["chol"] ,
    c = over_50["target"] ,
);
# Customize the plot
ax.set(
    title = "age vs chol" ,
    xlabel = "age" ,
    ylabel = "chol"
)

# Add a legend
ax.legend( *scatter.legend_elements() , title = "target" );

# Add a horizontal line
ax.axhline(
    over_50["chol"].mean() ,
    linestyle = "--"
);

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1,
                               sharex=True,
                               figsize=(10, 8))

# Add data for ax0
scatter = ax0.scatter(over_50["age"],
                      over_50["chol"],
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(),
            color='b',
            linestyle='--',
            label="Average")


# Add data for ax1
scatter = ax1.scatter(over_50["age"],
                      over_50["thalach"],
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(),
            color='b',
            linestyle='--',
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %% [markdown]
# ## Customizing matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
